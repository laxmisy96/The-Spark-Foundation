# %% [markdown]
# # LAXMI YADAHALLI

# %% [markdown]
# # GRIPJAN2021

# %% [markdown]
# # TASK-8

# %% [markdown]
# # Timeline Analysis : Covid-19

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import matplotlib.colors as mcolors

# %% [markdown]
# IMPORTING DATA

# %%
df1 = pd.read_csv("Desktop\AgeGroupDetails.csv")
df2 = pd.read_csv("Desktop\HospitalBedsIndia.csv")
df3 = pd.read_csv("Desktop\ICMRTestingLabs.csv")
df4 = pd.read_csv("Desktop\IndividualDetails.csv")
df5 = pd.read_csv("Desktop\StatewiseTestingDetails.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# AGE ANALYSIS

# %%
df1.head()
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%

# %%
def plot_piechart(x, y, title):
    c = random.choices(list(mcolors.CSS4_COLORS.values()), k=10)
    _ = plt.figure(figsize=(10,10))
    _ = plt.title(title, size=20)
    _ = plt.pie(y, colors=c)
    _ = plt.legend(x, loc='best', fontsize=10)
    _ = plt.show()

# %%
plot_piechart(df1["AgeGroup"], df1["TotalCases"], "Age Distribution")

# %% [markdown]
#  EDA of number of beds and healthcare facilities

# %%
df2.head()
# Out:
#    Sno                   State/UT NumPrimaryHealthCenters_HMIS  \
# 0    1  Andaman & Nicobar Islands                           27
# 1    2             Andhra Pradesh                         1417
# 2    3          Arunachal Pradesh                          122
# 3    4                      Assam                         1007
# 4    5                      Bihar                         2007
#
#    NumCommunityHealthCenters_HMIS  NumSubDistrictHospitals_HMIS  \
# 0                               4                           NaN
# 1                             198                          31.0
# 2                              62                           NaN
# 3                             166                          14.0
# 4                              63                          33.0
#
#    NumDistrictHospitals_HMIS  TotalPublicHealthFacilities_HMIS  \
# 0                          3                                34
# 1                         20                              1666
# 2                         15                               199
# 3                         33                              1220
# 4                         43                              2146
#
#    NumPublicBeds_HMIS  NumRuralHospitals_NHP18  NumRuralBeds_NHP18  \
# 0                1246                       27                 575
# 1               60799                      193                6480
# 2                2320                      208                2136
# 3               19115                     1176               10944
# 4               17796                      930                6083
#
#    NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 0                        3                 500
# 1                       65               16658
# 2                       10                 268
# 3                       50                6198
# 4                      103                5936

# %%
df2 = df2[df2['State/UT'] != 'All India']

# %%
def plot_bar_graphs(x, y, title):
    c = random.choices(list(mcolors.CSS4_COLORS.values()), k=10)
    _ = plt.figure(figsize=(20, 12))
    _ = plt.barh(x, y, color=c)
    _ = plt.title(title, size=20)
    _ = plt.xticks(size=15)
    _ = plt.yticks(size=15)
    plt.show()

# %%
plot_bar_graphs(df2['State/UT'], df2['NumRuralHospitals_NHP18'], 'Number of Rural Hospitals in different regions')

# %%
plot_bar_graphs(df2['State/UT'], df2['NumRuralBeds_NHP18'], 'Number of Rural Beds in different regions')

# %%
plot_bar_graphs(df2['State/UT'], df2['NumUrbanHospitals_NHP18'], 'Number of Urban Hospitals in different regions')

# %%
plot_bar_graphs(df2['State/UT'], df2['NumUrbanBeds_NHP18'], 'Number of Urban Beds in different regions')

# %%
plot_bar_graphs(df2['State/UT'], df2['TotalPublicHealthFacilities_HMIS'], 'Number of Public Health Facilities in different regions')

# %%
plot_bar_graphs(df2['State/UT'], df2['NumPublicBeds_HMIS'], 'Number of Public Beds in different regions')

# %% [markdown]
# Verification of information

# %%
df3.head()
# Out:
#                                                  lab  \
# 0  ICMR-Regional Medical Research Centre, Port Blair
# 1  Tomo Riba Institute of Health & Medical Scienc...
# 2  Sri Venkateswara Institute of Medical Sciences...
# 3                Rangaraya Medical College, Kakinada
# 4               Sidhartha Medical College, Vijaywada
#
#                                              address  pincode        city  \
# 0  ICMR-Regional Medical Research Centre, Post Ba...   744103  Port Blair
# 1  National Highway 52A, Old Assembly Complex, Na...   791110  Naharlagun
# 2  Sri Venkateswara Institute of Medical Sciences...   517507    Tirupati
# 3  Rangaraya Medical College, Kakinada Pithampura...   533001    Kakinada
# 4  Siddhartha Medical College, Vijayawada NH 16 S...   520008  Vijayawada
#
#                          state                   type
# 0  Andaman and Nicobar Islands  Government Laboratory
# 1            Arunachal Pradesh        Collection Site
# 2               Andhra Pradesh  Government Laboratory
# 3               Andhra Pradesh  Government Laboratory
# 4               Andhra Pradesh  Government Laboratory

# %%
df3['state'].value_counts()
# Out:
# Maharashtra                                 39
# Tamil Nadu                                  26
# Telangana                                   19
# Delhi                                       18
# Uttar Pradesh                               17
# Karnataka                                   17
# Gujarat                                     14
# West Bengal                                 13
# Kerala                                      12
# Haryana                                     11
# Madhya Pradesh                              10
# Rajasthan                                    9
# Andhra Pradesh                               7
# Odisha                                       7
# Assam                                        6
# Bihar                                        6
# Punjab                                       5
# Jammu and Kashmir                            4
# Chhattisgarh                                 3
# Uttarakhand                                  3
# Himachal Pradesh                             3
# Jharkhand                                    3
# Chandigarh                                   3
# Manipur                                      2
# Arunachal Pradesh                            1
# Mizoram                                      1
# Dadra and Nagar Haveli and Daman and Diu     1
# Sikkim                                       1
# Goa                                          1
# Andaman and Nicobar Islands                  1
# Tripura                                      1
# Puducherry                                   1
# Ladakh                                       1
# Meghalaya                                    1
# Name: state, dtype: int64

# %%
_ = plt.figure(figsize=(30,10))
_ = plt.title('Number of labs', size=20)
_ = sns.countplot(x = "state", data = df3)
_ = plt.xticks(rotation=90)

# %%
_ = sns.countplot(x = "type", data = df3)

# %% [markdown]
# Validating Assumptions

# %%
df5.head()
# Out:
#          Date                        State  TotalSamples  Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0    1210.0      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0       NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0       NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0       NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0       NaN      33.0

# %%
df5_sort = df5.sort_values(by = 'TotalSamples', ascending=False).head()
df5_sort.head()
# Out:
#             Date       State  TotalSamples   Negative  Positive
# 1068  2020-05-20  Tamil Nadu      360068.0  3346311.0   13191.0
# 1067  2020-05-19  Tamil Nadu      348174.0   334839.0   12448.0
# 1066  2020-05-18  Tamil Nadu      337841.0   325546.0   11760.0
# 1065  2020-05-17  Tamil Nadu      326720.0   315019.0   11224.0
# 1064  2020-05-16  Tamil Nadu      313639.0   302523.0   10585.0

# %%
df5_sort1 = df5.sort_values(by = 'TotalSamples', ascending=True).head()
df5_sort1.head()
# Out:
#            Date     State  TotalSamples  Negative  Positive
# 765  2020-04-07   Mizoram          58.0       0.0       1.0
# 764  2020-04-06   Mizoram          58.0       0.0       1.0
# 804  2020-04-06  Nagaland          60.0      47.0       0.0
# 806  2020-04-11  Nagaland          70.0      70.0       0.0
# 805  2020-04-10  Nagaland          70.0      69.0       0.0

# %% [markdown]
# CONCLUSION: Tamil Nadu has the highest number of samples being tested.
# Mizoram and Nagaland have the lowest number of tested samples recorded for a day.
#
# We can see that towards the extremes the data is synced well as Tamil Nadu which has second highest testing facility does highest testing and Mizoram and Nagaland which have one of the lowest test centers do lowest testing.

# %% [markdown]
# # THIS IS THE END OF TASK-8

# %% [markdown]
# # THANKYOU
